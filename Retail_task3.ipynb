# %% [markdown]
# # The Spark Foundation
# # Name Imran Roshan
# # Data Science and business Intelligence Intership
# # Task 3- Exploratory Data Analysis - Retail

# %% [markdown]
# # Dataset is available at:: https://bit.ly/3i4rbWl

# %% [markdown]
# ## Importing all necessary Libraries

# %%
# importing necesssary libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Loading data sets

# %%
df = pd.read_csv("SampleSuperstore.csv")
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# 9991       0.2  19.3932
# 9992       0.0  13.3200
# 9993       0.0  72.9480

# %% [markdown]
# ## shape of data

# %%
df.shape
# Out:
# (9994, 13)

# %% [markdown]
# ## summary of data

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# ## checking null values

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# ## columns information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
# duplicate values
df.duplicated().sum()
# Out:
# 17

# %%
# unique values
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
df.Segment.value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
df.Discount.value_counts()
# Out:
# 0.00    4798
# 0.20    3657
# 0.70     418
# 0.80     300
# 0.30     227
# 0.40     206
# 0.60     138
# 0.10      94
# 0.50      66
# 0.15      52
# 0.32      27
# 0.45      11
# Name: Discount, dtype: int64

# %%
df.State.value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# Louisiana                 42
# South Carolina            42
# Nevada                    39
# Nebraska                  38
# New Mexico                37
# Iowa                      30
# New Hampshire             27
# Kansas                    24
# Idaho                     21
# Montana                   15
# South Dakota              12
# Vermont                   11
# District of Columbia      10
# Maine                      8
# North Dakota               7
# West Virginia              4
# Wyoming                    1
# Name: State, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# ## chaning data form int to object
# Postal Code   9994 non-null   int64

# %%
df['Postal Code'] = df['Postal Code'].astype('object')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   object
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(1), object(9)
# memory usage: 1015.1+ KB

# %% [markdown]
# Postal Code   9994 non-null   object

# %% [markdown]
# ## Count of duplicate values

# %%
df.duplicated().sum()
# Out:
# 17

# %% [markdown]
# ## remove 17 duplicate values

# %%
df.drop_duplicates(subset=None, keep='first', inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9977 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9977 non-null   object
#  1   Segment       9977 non-null   object
#  2   Country       9977 non-null   object
#  3   City          9977 non-null   object
#  4   State         9977 non-null   object
#  5   Postal Code   9977 non-null   object
#  6   Region        9977 non-null   object
#  7   Category      9977 non-null   object
#  8   Sub-Category  9977 non-null   object
#  9   Sales         9977 non-null   float64
#  10  Quantity      9977 non-null   int64
#  11  Discount      9977 non-null   float64
#  12  Profit        9977 non-null   float64
# dtypes: float64(3), int64(1), object(9)
# memory usage: 1.1+ MB

# %%
corr = df.corr()
sns.heatmap(corr, annot=True, cmap="Greens")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Droping Postal Code column
# As it creates the noise in the input

# %%
df = df.drop(['Postal Code'], axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9977 entries, 0 to 9993
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9977 non-null   object
#  1   Segment       9977 non-null   object
#  2   Country       9977 non-null   object
#  3   City          9977 non-null   object
#  4   State         9977 non-null   object
#  5   Region        9977 non-null   object
#  6   Category      9977 non-null   object
#  7   Sub-Category  9977 non-null   object
#  8   Sales         9977 non-null   float64
#  9   Quantity      9977 non-null   int64
#  10  Discount      9977 non-null   float64
#  11  Profit        9977 non-null   float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 1013.3+ KB

# %%
corr = df.corr()
sns.heatmap(corr, annot= True, cmap="Greens")
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df, hue="Ship Mode")

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5955
# Second Class      1943
# First Class       1537
# Same Day           542
# Name: Ship Mode, dtype: int64

# %%
sns.countplot(x=df['Ship Mode'])
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='count'>

# %%
print(df['Segment'].value_counts())
sns.pairplot(df, hue="Segment")
# Out:
# Consumer       5183
# Corporate      3015
# Home Office    1779
# Name: Segment, dtype: int64

# %%
sns.countplot(x=df['Segment'],data= df, palette = "gist_ncar")
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='count'>

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    6012
# Furniture          2118
# Technology         1847
# Name: Category, dtype: int64

# %%
sns.countplot("Category", data=df , palette ="GnBu")
# Out:
# C:\Users\IMRAN ROSHAN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %%
sns.pairplot(df,hue="Category")

# %%
print(df['Sub-Category'].value_counts)
plt.figure(figsize=(15,12))
df["Sub-Category"].value_counts().plot.pie(autopct='%1.1f%%')
plt.legend(loc="upper left")
plt.show()
# Out:
# <bound method IndexOpsMixin.value_counts of 0         Bookcases
# 1            Chairs
# 2            Labels
# 3            Tables
# 4           Storage
#            ...
# 9989    Furnishings
# 9990    Furnishings
# 9991         Phones
# 9992          Paper
# 9993     Appliances
# Name: Sub-Category, Length: 9977, dtype: object>

# %% [markdown]
# # Resultant Observation from above
# ## In Sub-Categories:
# maxim in [Binders, Paper, Furnshings, Phones, Storage, Art, Accessories]
#
# minmum in[Copiers, Machines, Supplies]

# %%
print(df['State'].value_counts())
plt.figure(figsize=(15,12))
sns.countplot(x="State", data = df, palette="tab10", order = df["State"].value_counts().index)
plt.xticks(rotation=90)
plt.show()
# Out:
# California              1996
# New York                1127
# Texas                    983
# Pennsylvania             586
# Washington               502
# Illinois                 491
# Ohio                     468
# Florida                  383
# Michigan                 254
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   123
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# Louisiana                 42
# South Carolina            42
# Nevada                    39
# Nebraska                  38
# New Mexico                37
# Iowa                      30
# New Hampshire             27
# Kansas                    24
# Idaho                     21
# Montana                   15
# South Dakota              12
# Vermont                   11
# District of Columbia      10
# Maine                      8
# North Dakota               7
# West Virginia              4
# Wyoming                    1
# Name: State, dtype: int64

# %% [markdown]
# # Highest number of buyers are from California and NewYork!!!

# %%
df.hist(figsize=(10,10), bins=50)
plt.show()

# %% [markdown]
# # Most customers tends to buy quantity of 2 and 3
# # Discount give maximum is 0 to 20 Percent

# %%
plt.figure(figsize=(10,8))
df['Region'].value_counts().plot.pie(autopct='%1.1f%%')
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# # Correlation for Profit VS Discount:

# %%
fig,ax=plt.subplots(figsize=(20,8))
ax.scatter(df['Sales'],df["Profit"])
ax.set_xlabel("Sales")
ax.set_ylabel("profits")
plt.show()
print("------------------------------------------------------------------------------------------------------------")
sns.lineplot(x='Discount', y="Profit", label='Profit', data=df)
plt.legend()
plt.show()
# Out:
# ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # No Correlation between profit and discount!!!

# %%
sns.lineplot(x="Quantity", y="Profit", data =df)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df.groupby('Segment')[['Profit','Sales']].sum().plot.bar(color=['pink','blue'], figsize=(8,5))
plt.ylabel("Profit/loss and sales")
plt.show()

# %% [markdown]
# # Profit & Sales are maximum in consumer segment and minimum in Home Office Segment!!!

# %%
plt.figure(figsize=(12,8))
plt.title("Segment wise Sales in each Region")
sns.barplot(x="Region", y="Sales", data = df, hue="Segment", order = df['Region'].value_counts().index, palette="rocket")
plt.xlabel('Region', fontsize=15)
plt.show()
print("Segment wise sales are almost same in every region")
# Out:
# Segment wise sales are almost samw in every region

# %%
df.groupby('Region')[['Profit','Sales']].sum().plot.bar(color=['blue','red'], figsize=(8,5))
plt.ylabel("Profit/Loss and Sales")
plt.show()
print("Profit and sales are maximum in west region and minimum in south region")
# Out:
# Profit and sales are maximum in west region and minimum in south region

# %%
ps = df.groupby('State')[['Sales','Profit']].sum().sort_values(by="Sales",ascending=False)
ps[:].plot.bar(color=['blue','orange'], figsize=(15,8))
plt.title("Profit/loss and Sales across states")
plt.xlabel("States")
plt.ylabel('Profit/loss and Sales')
plt.show()

# %% [markdown]
# # high profit is for california, new york
# # loss is for texas, Pennsylvania,Ohio

# %%
t_states = df['State'].value_counts().nlargest(10)
t_states
# Out:
# California        1996
# New York          1127
# Texas              983
# Pennsylvania       586
# Washington         502
# Illinois           491
# Ohio               468
# Florida            383
# Michigan           254
# North Carolina     249
# Name: State, dtype: int64

# %%
df.groupby("Category")[['Profit','Sales']].sum().plot.bar(color=['yellow','purple'],alpha=0.9, figsize=(8,5))
plt.ylabel("Profit/Loss and Sales")
plt.show()

# %% [markdown]
# # As a business manager, try to find out the week areas where you can work to make more profit?
# ## Technology and Office Suppliers have high profit
# ## Furniture have less profit

# %%
ps = df.groupby('Sub-Category')[['Sales','Profit']].sum().sort_values(by="Sales",ascending=False)
ps[:].plot.bar(color=['red','lightblue'], figsize=(15,8))
plt.title("Profit/loss and Sales across states")
plt.xlabel("Sub-Category")
plt.ylabel('Profit/loss and Sales')
plt.show()

# %%
print("Resultant Observation form above   ||  phones sub-category have high sales"
      "|| chairs have high sales but less profit compared to phones"
      
      " || Tables and Bookmarks sub-catgory facing huge loss")
# Out:
# Resultant Observation form above   ||  phones sub-category have high sales|| chairs have high sales but less profit compared to phones || Tables and Bookmarks sub-catgory facing huge loss
